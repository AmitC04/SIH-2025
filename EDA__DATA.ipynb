# %%
# !pip install ydata-profiling --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=f40b8bc04c23dd559db15b2ee4872c53012a0a01e9058f9f58f8c865faf2094d
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
# ...

# %% [markdown]
# # **NE_WaterQuality_with_Diseases**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
url = "https://raw.githubusercontent.com/AmitC04/SIH-2025/main/NE_WaterQuality_with_Diseases.csv"
df = pd.read_csv(url)
print("Shape of dataset:", df.shape)
print("\nInfo:\n")
print(df.info())
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicates:", df.duplicated().sum())
print("\nStatistics:\n")
print(df.describe(include="all"))
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
for col in df.select_dtypes(include='object').columns:
    plt.figure(figsize=(6,4))
    sns.countplot(y=col, data=df, order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.show()
profile = ProfileReport(df, title="EDA Report - Water Quality with Diseases")
profile.to_file("EDA_Report_Diseases.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Shape of dataset: (296, 26)
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S. No.             296 non-null    int64
#  1   State              296 non-null    object
#  2   District           296 non-null    object
#  3   Location           296 non-null    object
#  4   Longitude          296 non-null    float64
#  5   Latitude           296 non-null    float64
#  6   Year               296 non-null    int64
# ...

# %% [markdown]
# # **NE_WaterQuality_with_RiskLevels**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
url = "https://raw.githubusercontent.com/AmitC04/SIH-2025/main/NE_WaterQuality_with_RiskLevels.csv"
df = pd.read_csv(url)
print("Shape of dataset:", df.shape)
print("\nInfo:\n")
print(df.info())
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicates:", df.duplicated().sum())
print("\nStatistics:\n")
print(df.describe(include="all"))
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
for col in df.select_dtypes(include='object').columns:
    plt.figure(figsize=(6,4))
    sns.countplot(y=col, data=df, order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.show()
profile = ProfileReport(df, title="EDA Report - Water Quality with Diseases")
profile.to_file("EDA_Report_Diseases.html")
# Out:
# Shape of dataset: (296, 25)
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S. No.          296 non-null    int64
#  1   State           296 non-null    object
#  2   District        296 non-null    object
#  3   Location        296 non-null    object
#  4   Longitude       296 non-null    float64
#  5   Latitude        296 non-null    float64
#  6   Year            296 non-null    int64
#  7   pH              296 non-null    float64
#  8   EC (µS/cm at    296 non-null    int64
#  9   CO3 (mg/L)      296 non-null    int64
#  10  HCO3            296 non-null    int64
#  11  Cl (mg/L)       296 non-null    int64
#  12  F (mg/L)        296 non-null    float64
#  13  SO4             296 non-null    int64
#  14  NO3             296 non-null    int64
#  15  PO4             296 non-null    object
# ...

# %% [markdown]
# # **EDA OF RAW DATA USED : FOR TRAINING THE MODEL**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# Correctly read Excel file
url = "https://raw.githubusercontent.com/AmitC04/SIH-2025/main/final_nhs-wq_pre_2023_compressed.xlsx"
df = pd.read_excel(url)

print("Shape of dataset:", df.shape)
print("\nInfo:\n")
print(df.info())
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicates:", df.duplicated().sum())
print("\nStatistics:\n")
print(df.describe(include="all"))

# Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Histograms for numeric columns
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# Countplots for categorical columns
for col in df.select_dtypes(include='object').columns:
    plt.figure(figsize=(6,4))
    sns.countplot(y=col, data=df, order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.show()

# Generate EDA report
profile = ProfileReport(df, title="EDA Report - Water Quality with Diseases")
profile.to_file("EDA_Report_Diseases.html")
# Out:
# Shape of dataset: (16776, 24)
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16776 entries, 0 to 16775
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S. No.          16776 non-null  int64
#  1   State           16776 non-null  object
#  2   District        16776 non-null  object
#  3   Location        16745 non-null  object
#  4   Longitude       16774 non-null  object
#  5   Latitude        16773 non-null  object
#  6   Year            16776 non-null  int64
#  7   pH              16776 non-null  object
#  8   EC (µS/cm at    16776 non-null  object
#  9   CO3 (mg/L)      16776 non-null  object
#  10  HCO3            16776 non-null  object
#  11  Cl (mg/L)       16776 non-null  object
#  12  F (mg/L)        16776 non-null  object
#  13  SO4             16776 non-null  object
#  14  NO3             16776 non-null  object
#  15  PO4             16776 non-null  object
# ...

# %%
profile.to_file("EDA_Report_Diseases.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
